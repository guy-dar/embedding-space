# %% [markdown]
# ## Init

# %%
import numpy as np
from tabulate import tabulate
import torch
from torch import nn
from copy import deepcopy
from transformers import (AutoModelForCausalLM, AutoTokenizer)
from utils import top_tokens, top_matrix_tokens

# %% [markdown]
# ## Extract Parameters

# %%
gpt = AutoModelForCausalLM.from_pretrained("gpt2-medium")
gpt_tokenizer = tokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
emb = gpt.get_output_embeddings().weight.data.T.detach()

num_layers = gpt.config.n_layer
num_heads = gpt.config.n_head
hidden_dim = gpt.config.n_ctx
head_size = hidden_dim // num_heads

K = torch.cat([gpt.get_parameter(f"transformer.h.{j}.mlp.c_fc.weight").T
                           for j in range(num_layers)]).detach()
V = torch.cat([gpt.get_parameter(f"transformer.h.{j}.mlp.c_proj.weight")
                           for j in range(num_layers)]).detach()
W_Q, W_K, W_V = torch.cat([gpt.get_parameter(f"transformer.h.{j}.attn.c_attn.weight") 
                           for j in range(num_layers)]).detach().chunk(3, dim=-1)
W_O = torch.cat([gpt.get_parameter(f"transformer.h.{j}.attn.c_proj.weight") 
                           for j in range(num_layers)]).detach()

K_heads = K.reshape(num_layers, -1, hidden_dim)
V_heads = V.reshape(num_layers, -1, hidden_dim)
d_int = K_heads.shape[1]

W_V_heads = W_V.reshape(num_layers, hidden_dim, num_heads, head_size).permute(0, 2, 1, 3)
W_O_heads = W_O.reshape(num_layers, num_heads, head_size, hidden_dim)
W_Q_heads = W_Q.reshape(num_layers, hidden_dim, num_heads, head_size).permute(0, 2, 1, 3)
W_K_heads = W_K.reshape(num_layers, hidden_dim, num_heads, head_size).permute(0, 2, 1, 3)

# %% [markdown]
# ## Interpret Parameters

# %% [markdown]
# ### FF

# %%
E1 = emb
E2 = E1.T #(E1 + 3 * torch.eye(*E1.shape)).pinverse()

# %%
i1, i2 = np.random.randint(24), np.random.randint(4096)
print(i1, i2)
f = lambda x: x # - x.mean()
print(tabulate([*zip(
    top_tokens(f(K_heads[i1, i2]) @ E2.T, k=200, tokenizer=tokenizer),
    top_tokens(f(V_heads[i1, i2]) @ E1, k=200, tokenizer=tokenizer),
    top_tokens(-f(K_heads[i1, i2]) @ E2.T, k=200, tokenizer=tokenizer),
    top_tokens(-f(V_heads[i1, i2]) @ E1, k=200, tokenizer=tokenizer),
)], headers=['K', 'V', '-K', '-V']))
# Out:
# 0 835
# K               V                   -K                  -V
# --------------  ------------------  ------------------  --------------
# Views           #qus                Dum                 #odied
# Hobby           #JM                 wiret               Â®
# #agement        Pyr                 #milo               #False
# #Own            Jav                 mustard             #ãĥķãĤ©
# views           #agall              extrad              redistributed
# OWN             #hra                theorem             #locking
# #own            Nab                 #aundering          ventured
# #Community      markers             laundering          #Economic
# #Activity       #beck               Rib                 #rosis
# hobby           #FUL                hypot               scarce
# #Self           #azaki              swe                 poppy
# Owner           #tale               #htar               #bane
# #ession         drag                tuberculosis        #argo
# Owners          rally               dele                #enei
# #Artist         Tanaka              clot                #onics
# Own             lap                 #rax                #OSS
# #Social         surge               Warrant             #inance
# #Professional   Camel               gul                 #ãĥ¢
# interests       #åĤ                 influenza           Chains
# #community      Flare               #rays               favoured
# Artist          #Rocket             blot                #ionage
# #Traditional    sway                #sbm                counterfe
# #View           #hound              stockpile           #orial
# #Comment        #/?                 choking             #igenous
# #Activ          #fire               #ti                 #aeda
# Interest        Carbuncle           nod                 #ropolitan
# Passion         Revival             #DERR               #ROM
# Activities      Sak                 0004                #agu
# hobbies         thread              #.................  Banks
# affiliation     stall               deferred            #estival
# affili          #YA                 clause              Wyn
# Groups          #bilt               #stab               Osborne
# #AGE            blitz               submarines          Bridges
# #uild           haste               goaltender          #scl
# #Author         pitfalls            fle                 #nai
# #Owner          #Score              counterfe           visualize
# passions        #/#                 Carlo               #ensation
# #self           #çĶ°                diarrhea            LSD
# community       #bridge             stret               #valued
# self            Hound               #xit                #locks
# #owner          Springs             Clause              #mi
# activity        #nels               #.................  #oux
# #groups         Gum                 #atable             KM
# #artist         Peak                warheads            #ults
# #age            #horse              bribery             #herty
# Entertainment   yak                 stockp              Pes
# owner           Countdown           lich                #LOCK
# Professional    lag                 flora               ops
# #AGES           #idable             tomatoes            #onse
# Creative        wob                 imperialism         #toe
# #IGHT           Chau                potatoes            emphas
# Friends         Avatar              substitution        #thia
# #comments       #Ĥª                 XII                 actionGroup
# #Profile        failings            #Ã§a                #uture
# beliefs         Barrier             seq                 #Products
# #avid           Lad                 #á¸                 #acies
# Community       duck                kernels             #arcity
# #Interest       inev                Marshal             #opez
# Actions         #çĲ                 powd                Investigative
# #Current        snail               Ramos               Females
# #amer           #AE                 #oln                #Peace
# #anger          Rocket              #inator             Hort
# #owners         pace                stuffing            #raphics
# Belief          #starter            Statue              #oded
# #AMA            Room                lieutenant          #ynthesis
# #Amazon         Gap                 clauses             Learned
# #social         durability          #å°Ĩ                #erences
# groups          Destiny             #cised              MISS
# Comments        #Gab                glaciers            circulated
# Artists         #angs               doubling            #TING
# #agen           rake                crabs               #olitical
# #Friends        #usercontent        quadru              #Ott
# #oman           Grav                typh                #ociated
# #ama            #iq                 beetles             #orously
# #Sport          #Pros               lettuce             Indigenous
# Media           Naj                 malnutrition        fuzz
# #iance          sake                mushrooms           #olitics
# Religious       Galile              #strate             #oks
# #song           Faust               coli                #oration
# #amazon         countdown           rib                 #ression
# #obbies         #wagon              ta                  #Sat
# enjoyed         anim                Tanaka              #locked
# #occup          Point               goalie              chi
# #Occup          #¶ħ                 absor               #thodox
# occupation      Ares                Browne              omission
# #activ          #OME                #missible           #oteric
# Activ           Camer               XI                  #venue
# enjoyment       AH                  Mae                 #matical
# #essions        #????????           sled                Kahn
# Self            manual              clay                False
# artist          gulf                siph                Entered
# Enjoy           #delay              Mortal              #vernment
# #Media          Ryder               TheNitromeFan       #allic
# #professional   grunt               shortages           cultiv
# enjoys          Creek               Clone               #atible
# #Share          stomach             Crimean             learnt
# Profession      Jah                 pineapple           #entious
# Previous        millisec            ï¿½ï¿½ï¿½ï¿½ï¿½...  #archy
# Traditional     Bard                humid               #actively
# Religion        vet                 kidnapping          Boyd
# Activity        bloom               #decl               #achel
# #obby           #auga               stain               #hid
# own             Gow                 intercept           Taxes
# #Group          #myra               indict              #ederal
# communal        #cade               000000              #anium
# #OWN            #aber               legion              helicop
# #author         Abyss               mete                psychedel
# interest        #zza                #nesium             #Mis
# opinions        Flow                #patch              #ronic
# #ifestyle       #EA                 submarine           compe
# friends         Jindal              smuggling           #Commerce
# #media          Rew                 #byss               #vertisements
# owners          #agi                extradition         #odies
# ACTION          Mare                Cipher              #ancouver
# #isan           #erman              gases               #artment
# #Enjoy          rout                2024                #visory
# Action          #ike                colonel             #amation
# #estone         #eers               vomiting            Poverty
# View            trail               cipher              (<
# followers       cheeks              Tib                 #rals
# #comment        blazing             Rept                #ribute
# #religious      #EP                 fugitive            #udget
# enjoy           #indal              #aband              #itle
# Contact         crate               #glas               #emporary
# #ages           pneumonia           refuel              SI
# #Business       surges              #termin             #Cash
# #Blog           #QL                 memorandum          #ellectual
# VIEW            #astrous            courier             #Drug
# entertainment   #tion               #QB                 #eny
# #views          Ribbon              syrup               #utations
# Facebook        Tsuk                runoff              Hod
# Occup           #dal                Hort                incorporated
# view            rushes              scal                #isexual
# Comment         #hea                #NetMessage         #oreal
# #Action         #properties         prim                #Technology
# arts            lull                manifold            emphasized
# enthusiast      #EngineDebug        dodging             #rencies
# Communities     #Loader             #kas                #ochemistry
# #Comments       heartbeat           diarr               #Ã³
# professional    #hub                ãĢĮ                 #Marginal
# #Facebook       Gau                 #uple               #oyd
# #isans          #antes              Directive           #orrow
# personality     #henko              #iard               Instruments
# opinion         #jee                ferry               interacted
# organisations   #lv                 bait                #otton
# Likes           Spiral              rede                #orescence
# social          Savage              Jacques             contamin
# #updated        pause               climates            #-+-+-+-+
# Career          catering            Barbar              Spiritual
# artistic        Yard                #trap               #oring
# Progress        Axis                #assic              #Float
# Organizations   healer              #borgh              Churches
# religious       #Ã§a                traps               ));
# #interest       raging              Gob                 McKenzie
# #essional       pu                  defer               #utation
# #aday           #zing               seeds               #":""},{"
# #blogs          Cowboy              wheat               Tuc
# comments        disadvantages       Libya               #ipped
# likes           #etter              famine              #"}],"
# #Music          #______________...  smuggled            #mble
# religion        staggered           Nept                Chong
# OCD             Blackburn           uranium             #ancock
# #Previous       #hus                Raptors             #Financial
# owns            plateau             ration              teased
# #GOP            #Bern               Ney                 #kHz
# Happiness       rotten              submar              circulate
# Aff             Alexandria          Powder              #duc
# #amy            RU                  #geant              coined
# #Party          RSS                 ceilings            mistaken
# #APP            Mang                ribs                #oney
# #ony            Rifle               piles               #ournal
# organisation    #ful                Khe                 #focused
# #ESSION         #sburg              Luxem               CO
# friendships     delay               marsh               uncond
# advocacy        #joy                #quickShipAvail...  #Si
# #Freedom        grading             #.................  #imag
# #Registered     typh                Lt                  Continental
# #aff            Prairie             torped              #colour
# #Posted         #Va                 #transfer           #ADVERTISEMENT
# professionally  #é¾                 Lieutenant          #keyes
# Social          galvan              pist                innovate
# comment         relativity          rip                 #orage
# Craft           #wiki               fetal               #rodu
# group           DRAG                #çī                 Hutchinson
# #Disney         Halls               Legion              #mable
# #Style          Ham                 dra                 FI
# communities     #¥µ                 bowling             #fitted
# #Play           politician          boo                 #ashed
# organization    #lund               flashback           #ostic
# #ACA            #pages              Kr                  Important
# VID             Ard                 halftime            TI
# enthusiasts     fire                mitigating          #isse
# Relations       timer               dehyd               #Services
# Popular         timetable           crocod              dope
# enthus          Hog                 radiation           #overty
# passion         sack                #åº                 #Context
# #custom         #pu                 #hra                #earable
# organizations   #yang               Ve                  #ikh
# #ERSON          mete                #olini              #onia
# Share           #tan                0000                speculation

# %% [markdown]
# ### Attention Parameters
